# %%
import pandas as pd 
import requests
from tqdm import tqdm
import json
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
print('Packages Imported')
# Out:
# Packages Imported

# %%
# Set Spotify Credentials
clientId = "ENTER CLIENT ID HERE"
clientSecret = "ENTER CLIENT SECRET HERE"

os.environ["SPOTIPY_CLIENT_ID"] = clientId
os.environ["SPOTIPY_CLIENT_SECRET"] = clientSecret
os.environ["SPOTIPY_REDIRECT_URI"] = "http://localhost:8888/callback"

# %%
username = "ENTER USERNAME HERE"
client_credentials_manager = SpotifyClientCredentials(client_id=clientId, client_secret=clientSecret) 
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
scope = 'user-top-read'
token = util.prompt_for_user_token(username, scope)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for", username)

# %%
if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_top_tracks(limit=50,offset=0,time_range='short_term')
    for song in range(500):
        list = []
        list.append(results)
        with open('top50_data.json', 'w', encoding='utf-8') as f:
            json.dump(list, f, ensure_ascii=False, indent=4)
else:
    print("Can't get token for", username)

# %%
with open('top50_data.json', errors='ignore') as f:
  data = json.load(f)

# %%
list_of_results = data[0]["items"]
list_of_song_names = []
list_of_song_uri = []
list_of_durations_ms = []
list_of_explicit = []
list_of_artist_names = []
list_of_artist_uri = []
list_of_albums = []
list_of_album_covers = []
list_of_popularity = []

for result in list_of_results:
    result["album"]
    list_of_songs = result["name"]
    list_of_song_names.append(list_of_songs)
    song_uri = result["uri"]
    list_of_song_uri.append(song_uri)
    list_of_duration = result["duration_ms"]
    list_of_durations_ms.append(list_of_duration)
    song_explicit = result["explicit"]
    list_of_explicit.append(song_explicit)
    this_artists_name = result["artists"][0]["name"]
    list_of_artist_names.append(this_artists_name)
    this_artists_uri = result["artists"][0]["uri"]
    list_of_artist_uri.append(this_artists_uri)
    this_album = result["album"]["name"]
    list_of_albums.append(this_album)
    this_album_cover = result["album"]["images"][0]["url"]
    list_of_album_covers.append(this_album_cover)
    song_popularity = result["popularity"]
    list_of_popularity.append(song_popularity)

# %%
# USER 1 - Adds top 50-100 songs from the first user
if token:
    sp = spotipy.Spotify(auth=token)
    results = sp.current_user_top_tracks(limit=50,offset=49,time_range='long_term')
    for song in range(500):
        list = []
        list.append(results)
        with open('top50_data.json', 'w', encoding='utf-8') as f:
            json.dump(list, f, ensure_ascii=False, indent=4)
else:
    print("Can't get token for", username)

# %%
# USER 1 - Creates the json file with all the info for the top 50-100 songs
with open('top50_data.json', errors='ignore') as f:
  data = json.load(f)

# %%
# USER 1 - Adds top 50-100 songs to the lists which will later go in the dataframe
for result in list_of_results:
    result["album"]
    list_of_songs = result["name"]
    list_of_song_names.append(list_of_songs)
    song_uri = result["uri"]
    list_of_song_uri.append(song_uri)
    list_of_duration = result["duration_ms"]
    list_of_durations_ms.append(list_of_duration)
    song_explicit = result["explicit"]
    list_of_explicit.append(song_explicit)
    this_artists_name = result["artists"][0]["name"]
    list_of_artist_names.append(this_artists_name)
    this_artists_uri = result["artists"][0]["uri"]
    list_of_artist_uri.append(this_artists_uri)
    this_album = result["album"]["name"]
    list_of_albums.append(this_album)
    this_album_cover = result["album"]["images"][0]["url"]
    list_of_album_covers.append(this_album_cover)
    song_popularity = result["popularity"]
    list_of_popularity.append(song_popularity)

# %%
all_songs = pd.DataFrame(
    {'song': list_of_song_names,
     'song_uri': list_of_song_uri,
     'duration_ms': list_of_durations_ms,
     'explicit': list_of_explicit,
     'artist': list_of_artist_names,
     'artist_uri': list_of_artist_uri,
     'album': list_of_albums,
     'album_cover': list_of_album_covers,
     'popularity': list_of_popularity
     
    })

all_songs_saved = all_songs.to_csv('top100_songs.csv')
all_songs
# Out:
#                                                  song  \
# 0                                  Sincerity Is Scary
# 1                     What A Time (feat. Niall Horan)
# 2                                             Holiday
# 3                             Put A Little Love On Me
# 4   Even When/The Best Part - From "High School Mu...
# ..                                                ...
# 95                                        Silhouettes
# 96                  Slide (feat. Frank Ocean & Migos)
# 97                                              Sofia
# 98                                              Girls
# 99                                  When She Loved Me
#
#                                 song_uri  duration_ms  explicit  \
# 0   spotify:track:6HguG9HRb1Ke1bhihfE4m8       225955     False
# 1   spotify:track:5WtfUKzXircvW8l5aaVZWT       173306     False
# 2   spotify:track:4wtxSmTTeg6CiuhwIVKv0b       138293     False
# 3   spotify:track:7LyBwug9tJgbaEzRCqtY78       224585     False
# 4   spotify:track:30UszgTxEuJVG5SUFyBffT       106880     False
# ..                                   ...          ...       ...
# 95  spotify:track:612JlaWJl5l6VIrcBck5QB       177773     False
# 96  spotify:track:6gpcs5eMhJwax4mIfKDYQk       230813      True
# 97  spotify:track:7B3z0ySL9Rr0XvZEAjWZzM       188386     False
# 98  spotify:track:2zyz614fJRrqQXW1q0sY1c       254620      True
# 99  spotify:track:3198LMj0bpnXj8Mb1GLo3u       187709     False
#
#              artist                             artist_uri  \
# 0          The 1975  spotify:artist:3mIj9lX2MWuHmhNCA7LSCW
# 1    Julia Michaels  spotify:artist:0ZED1XzwlLHW4ZaG4lOT6m
# 2   Vampire Weekend  spotify:artist:5BvJzeQpmsdsFp4HGUYUEx
# 3       Niall Horan  spotify:artist:1Hsdzj7Dlq2I7tHP7501T4
# 4    Olivia Rodrigo  spotify:artist:1McMsnEElThX1knmY4oliG
# ..              ...                                    ...
# 95     Colony House  spotify:artist:6R664N4cEza3eORSqKSgO4
# 96    Calvin Harris  spotify:artist:7CajNmpbOovFoOoasH2HaY
# 97           Clairo  spotify:artist:3l0CmX0FuQjFxr8SK7Vqag
# 98         The 1975  spotify:artist:3mIj9lX2MWuHmhNCA7LSCW
# 99        Lyn Lapid  spotify:artist:4pfy05cNNTacuOQ6SiSu4v
#
#                                                 album  \
# 0           A Brief Inquiry Into Online Relationships
# 1                              Inner Monologue Part 1
# 2                                              Contra
# 3                                  Heartbreak Weather
# 4   Even When/The Best Part [From "High School Mus...
# ..                                                ...
# 95                                 When I Was Younger
# 96                  Slide (feat. Frank Ocean & Migos)
# 97                                           Immunity
# 98                          The 1975 (Deluxe Version)
# 99                                  When She Loved Me
#
#                                           album_cover  popularity
# 0   https://i.scdn.co/image/ab67616d0000b2736c5820...          66
# 1   https://i.scdn.co/image/ab67616d0000b2737e7069...          85
# 2   https://i.scdn.co/image/ab67616d0000b2736fb611...          50
# 3   https://i.scdn.co/image/ab67616d0000b2733d13e9...          72
# 4   https://i.scdn.co/image/ab67616d0000b273dbdb05...          68
# ..                                                ...         ...
# 95  https://i.scdn.co/image/ab67616d0000b27326c197...          63
# 96  https://i.scdn.co/image/ab67616d0000b2731e439a...          74
# 97  https://i.scdn.co/image/ab67616d0000b27333ccb6...          83
# 98  https://i.scdn.co/image/ab67616d0000b273ebcc3e...          58
# 99  https://i.scdn.co/image/ab67616d0000b27348b6f3...          62
#
# [100 rows x 9 columns]
